# %%
## Notebooke to learn about gragh networks
import networkx  as nx
import matplotlib.pyplot as plt

# %%
g=nx.Graph()
g.add_edge(1,2)
g.add_edge(2,3,weight=0.9)
nx.draw_spring(g,with_labels=True)
plt.show()
